# %% [markdown]
# <a href="https://colab.research.google.com/github/molluIdontknow/Model/blob/main/ELEalgo_random_forest%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing

# 1. 캘리포니아 하우싱 데이터셋 로드
housing = fetch_california_housing(as_frame=True)
df = housing.frame
CSV_FILEPATH = "california_housing.csv"
df.to_csv(CSV_FILEPATH, index=False)

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# ==========================================
# 1. 설정 및 CSV 데이터 로드
# ==========================================
CSV_FILENAME = "california_housing.csv"
FEATURES = ["MedInc", "HouseAge", "AveRooms", "Population", "AveOccup", "Latitude", "Longitude"]
TARGET = "MedHouseVal"
n_estimators=100
random_state=42
n_jobs=-1

# 데이터 불러오기
df = pd.read_csv(CSV_FILENAME)
X = df[FEATURES].values
y = df[TARGET].values

# ==========================================
# 2. 랜덤 포레스트 모델 선언 및 학습
# ==========================================
print("\n=== 랜덤 포레스트 모델 학습 시작 ===")

# n_estimators: 결정 트리 개수, n_jobs=-1: 모든 CPU 코어 사용
model = RandomForestRegressor(n_estimators=n_estimators, random_state=random_state, n_jobs=n_jobs)
model.fit(X, y)

print("\n 파이프라인 연동 테스트 완료!")

# ==========================================
# 3. 무작위 추출 10개 샘플 평가
# ==========================================
# 전체 데이터셋 크기 중에서 무작위로 10개 인덱스 선택
random_indices = np.random.choice(len(df), size=10, replace=False)

# 선택된 무작위 인덱스의 데이터 추출
sample_x_subset = X[random_indices]
sample_y_subset = y[random_indices]

# 추론 실행
preds = model.predict(sample_x_subset)

# 실제값 및 예측값 정리
actuals = sample_y_subset.flatten()
predictions = preds.flatten()

# 절대 오차 및 오차율(%) 연산: |실제값 - 예측값| / 실제값 * 100
abs_error = np.abs(actuals - predictions)
error_rate_pct = (abs_error / np.maximum(actuals, 1e-8)) * 100

# 보기 쉽게 Pandas DataFrame으로 정리
result_df = pd.DataFrame({
    "원본 Index": random_indices,  # 몇 번째 행 데이터를 뽑았는지 확인용
    "실제값 (Actual)": np.round(actuals, 4),
    "예측값 (Pred)": np.round(predictions, 4),
    "절대 오차": np.round(abs_error, 4),
    "오차율 (%)": np.round(error_rate_pct, 2)
})

print("\n=== 📊 무작위 추출 10개 샘플 예측 결과 비교 ===")
print(result_df.to_string(index=False))
print("hi")
# Out:
# === 랜덤 포레스트 모델 학습 시작 ===
#
#  파이프라인 연동 테스트 완료!
#
# === 📊 무작위 추출 10개 샘플 예측 결과 비교 ===
#  원본 Index  실제값 (Actual)  예측값 (Pred)  절대 오차  오차율 (%)
#     18741         0.694      0.7256 0.0316     4.56
#     10802         4.714      4.7457 0.0317     0.67
#      5113         1.132      1.1576 0.0256     2.26
#     19154         2.140      2.1395 0.0005     0.02
#      5445         2.431      2.6717 0.2407     9.90
#     15382         2.083      1.9642 0.1188     5.70
#     14914         1.529      1.4864 0.0426     2.79
#        57         0.853      0.9236 0.0706     8.28
#      4561         3.125      2.6123 0.5127    16.41
#     20176         2.242      2.3170 0.0750     3.35
# hi

# %%
# !git clone https://github.com/molluIdontknow/Model.git
# Out:
# Cloning into 'Model'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
# %cd Model
# Out:
# /content/Model

# %%
# !pwd
# Out:
# /content/Model

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git add .
# !git commit -m "Update algorithm"
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git remote -v
# Out:
# origin	https://github.com/molluIdontknow/Model.git (fetch)
# origin	https://github.com/molluIdontknow/Model.git (push)

# %%
# !git config --global user.email "siwook060609@gmail.com"
